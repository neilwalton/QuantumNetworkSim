# %% [markdown]
# # Basic magic-state simulation

# %%
from pathlib import Path
import sys

repo_root = Path.cwd()
if repo_root.name == "examples":
    repo_root = repo_root.parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from magic_state_sim import *
sim = MagicStateSimulator(
    factory=MagicStateFactory(production_rate=2),
    source_memory=FiniteMemory(8),
    qpus=[QPU('qpu-0', QPUCommunicationMemory(8))],
    network=LossyNetwork(loss_probability=0.1, latency=1, seed=7),
    computation=FixedPeriodicComputation(period=2),
)
sim.run(1000).as_dict()
# Out:
# {'states_created': 2000,
#  'states_accepted_by_memory': 2000,
#  'states_rejected_by_memory': 0,
#  'bell_pairs_attempted': 678,
#  'bell_pairs_created': 615,
#  'teleport_attempts': 615,
#  'teleport_successes': 615,
#  'teleport_failures': 0,
#  'completed_operations': 323,
#  'states_delivered': 614,
#  'states_consumed': 323,
#  'produced': 2000,
#  'admitted': 2000,
#  'sent': 615,
#  'delivered': 614,
#  'lost': 0,
#  'consumed': 323,
#  'failed_operations': 0}
